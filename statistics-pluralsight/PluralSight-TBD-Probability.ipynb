# %%
# Tim H 2024
# Video(s) that I followed along with for this Jupyter Notebook
# https://app.pluralsight.com/ilx/video-courses/4b4cdb5a-b0b9-4c17-8e5c-9d9e07e522a0/6890dda1-93e6-4d17-a91d-35d55fed4d46/19c91e79-319b-4796-a26e-0e9fed146dfb

# this example code from PluralSight is horribly inefficent at using memory

# %%
import random
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="darkgrid")

# %%
def flip(n):
    result = []
    for i in range(1, n+1):
        result.append(random.choice(['Heads', 'Tails']))
    return result

# %%
result = flip(10)
result
# Out:
# ['Heads',
#  'Heads',
#  'Tails',
#  'Tails',
#  'Tails',
#  'Heads',
#  'Heads',
#  'Heads',
#  'Heads',
#  'Heads']

# %%
plt.figure(figsize=(12, 8))

sns.countplot(x=result)

plt.xlabel('Coin Flip')
plt.title('Counts')

plt.show()

# %%
result = flip(100)

plt.figure(figsize=(12, 8))

sns.countplot(x=result)

plt.xlabel('Coin Flip')
plt.title('Counts')

plt.show()

# %%
result = flip(100000)
plt.figure(figsize=(12, 8))
sns.countplot(x=result)
plt.xlabel('Coin Flip')
plt.title('Counts')

plt.show()
