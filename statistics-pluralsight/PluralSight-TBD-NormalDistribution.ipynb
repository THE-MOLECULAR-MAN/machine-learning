# %%
# Tim H 2024
# Video(s) that I followed along with for this Jupyter Notebook
# https://app.pluralsight.com/ilx/video-courses/4b4cdb5a-b0b9-4c17-8e5c-9d9e07e522a0/6890dda1-93e6-4d17-a91d-35d55fed4d46/59843256-b924-4866-859b-d839fa534c5c

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(style="darkgrid")

# %%
normally_distributed_data = np.random.normal(loc=0, scale=1, size=100000)
normally_distributed_data[:10]
# Out:
# array([ 0.16661044, -0.49415415,  0.38869546, -1.97628341, -2.10515813,
#        -0.24768797, -0.50145869, -0.32569282,  1.49316366, -1.40967604])

# %%
sample_mean = np.mean(normally_distributed_data)
sample_mean
# Out:
# -0.0009673373999351057

# %%
# median
sample_med = np.median(normally_distributed_data)
sample_med
# Out:
# -0.0024186114815731435

# %%
# standard deviation
sample_std = np.std(normally_distributed_data)
sample_std
# Out:
# 0.9996176766955336

# %%
plt.figure(figsize=(12,8))
sns.histplot(x=normally_distributed_data)

plt.axvline(x=sample_mean, color='yellow', linestyle='-')
plt.axvline(x=sample_med, color='r', linestyle='-.')

plt.xlabel('Values', fontsize='15')
plt.ylabel('Probability', fontsize='15')

plt.show()

# %%
#KDE Plot - Kernel Density Estimate
# analogous to a historgram but without the bins
plt.figure(figsize=(12,8))

sns.kdeplot(x=normally_distributed_data)
plt.title('Normal Distribution', fontsize='15')

plt.axvline(x=sample_mean, color='yellow', linestyle='-')
plt.axvline(x=sample_med, color='r', linestyle='-.')

plt.xlabel('Values', fontsize='15')
plt.ylabel('Probability', fontsize='15')

plt.show()

# %%
# scale = 3 just means std dev = 3
normally_distributed_data_scale3 = np.random.normal(loc=0, scale=3, size=100000)

sns.kdeplot(x=normally_distributed_data)
sns.kdeplot(x=normally_distributed_data_scale3)
plt.title('Normal Distribution', fontsize='15')

plt.xlabel('X', fontsize='15')
plt.ylabel('Probability', fontsize='15')

plt.show()

# %%
# loc is the horizontal offset, the center of the bell curve
# in this case, the center of the bell curve is 2 and the stddev = 1
normally_distributed_data_loc2 = np.random.normal(loc=2, scale=1, size=100000)

sns.kdeplot(x=normally_distributed_data)
sns.kdeplot(x=normally_distributed_data_loc2)
plt.title('Normal Distribution', fontsize='15')

plt.xlabel('X', fontsize='15')
plt.ylabel('Probability', fontsize='15')

plt.show()
